# %%
# Import the dependencies.
import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

import requests

from citipy import citipy

#import the API key

from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)

lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list.

coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities

cities = []

# Identify the nearest city for each lat and long combo

for coordinate in coordinates:
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    
# If the city is uniqe, then we will add it to the cities list

    if city not in cities:
        
        cities.append(city)
        
len(cities)
# Out:
# 761

# %%
# Import the time library and the datetime module from the datetime lib

import time

# %%
## Create an empty list to hold the weather data

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

city_data = []

# Print the beginning of the logging

print("Beginning Data Retrieval     ")

print("-----------------------------")

# create the counters

record_count = 1

set_count = 1

# Loop through all the cities in our list

for i, city in enumerate(cities):
    
    # Group the cities in sets of 50 for the logging purposes
    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        
        record_count = 1
        
        time.sleep(60)
        
    # Create endpoint URL with each city
    
    city_url = url +"&q=" + city.replace(" ","+")
    
    # Log the URL, Record, and set numbers and the city
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record_count
    
    record_count += 1
    
    # Run an API request for each of the cities
    
    try:
        
        # Parse the json and retrive the data
        
        city_weather=requests.get(city_url).json()
        
        # Parse out the needed data
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into the city_data list
        
        city_data.append({"City": city.title(),
                         "Country": city_country,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Current Description": city_description})
    except:
        
        print("City not found. Skipping...")
        
        continue
        
# Indicate that Data Loading is complete.

print("-----------------------------")

print("Data Retrieval Complete      ")

print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pochutla
# Processing Record 2 of Set 1 | kihei
# Processing Record 3 of Set 1 | kodiak
# Processing Record 4 of Set 1 | mount gambier
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | plettenberg bay
# Processing Record 8 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 1 | khasan
# Processing Record 10 of Set 1 | tingi
# Processing Record 11 of Set 1 | dolores
# Processing Record 12 of Set 1 | guarapari
# Processing Record 13 of Set 1 | alyangula
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | lata
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 1 | lapithos
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | mendoza
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | vao
# Processing Record 26 of Set 1 | nome
# Processing Record 27 of Set 1 | sioux lookout
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | riberalta
# Processing Record 32 of Set 1 | cherskiy
# Processing Record 33 of Set 1 | lichinga
# Processing Record 34 of Set 1 | russell
# Processing Record 35 of Set 1 | beloha
# Processing Record 36 of Set 1 | caravelas
# Processing Record 37 of Set 1 | dikson
# Processing Record 38 of Set 1 | cabo san lucas
# Processing Record 39 of Set 1 | narsaq
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | iqaluit
# Processing Record 42 of Set 1 | ahipara
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | jijiga
# Processing Record 45 of Set 1 | qaanaaq
# Processing Record 46 of Set 1 | ola
# Processing Record 47 of Set 1 | touros
# Processing Record 48 of Set 1 | bathsheba
# Processing Record 49 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 1 | torbay
# Processing Record 1 of Set 2 | provideniya
# Processing Record 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 2 | bredasdorp
# Processing Record 4 of Set 2 | magnolia
# Processing Record 5 of Set 2 | deputatskiy
# Processing Record 6 of Set 2 | attur
# Processing Record 7 of Set 2 | victoria
# Processing Record 8 of Set 2 | sandi
# Processing Record 9 of Set 2 | palembang
# Processing Record 10 of Set 2 | port macquarie
# Processing Record 11 of Set 2 | grindavik
# Processing Record 12 of Set 2 | yar-sale
# Processing Record 13 of Set 2 | albany
# Processing Record 14 of Set 2 | hermanus
# Processing Record 15 of Set 2 | port alfred
# Processing Record 16 of Set 2 | husavik
# Processing Record 17 of Set 2 | salalah
# Processing Record 18 of Set 2 | sao filipe
# Processing Record 19 of Set 2 | lorengau
# Processing Record 20 of Set 2 | tiksi
# Processing Record 21 of Set 2 | haines junction
# Processing Record 22 of Set 2 | tuktoyaktuk
# Processing Record 23 of Set 2 | mabopane
# Processing Record 24 of Set 2 | hobart
# Processing Record 25 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 26 of Set 2 | busselton
# Processing Record 27 of Set 2 | laguna de duero
# Processing Record 28 of Set 2 | northam
# Processing Record 29 of Set 2 | evensk
# Processing Record 30 of Set 2 | los llanos de aridane
# Processing Record 31 of Set 2 | saskylakh
# Processing Record 32 of Set 2 | hasaki
# Processing Record 33 of Set 2 | lumeje
# Processing Record 34 of Set 2 | pangnirtung
# Processing Record 35 of Set 2 | flinders
# Processing Record 36 of Set 2 | verkh-usugli
# Processing Record 37 of Set 2 | labuhan
# Processing Record 38 of Set 2 | mahebourg
# Processing Record 39 of Set 2 | la ronge
# Processing Record 40 of Set 2 | aban
# Processing Record 41 of Set 2 | clarence town
# Processing Record 42 of Set 2 | upernavik
# Processing Record 43 of Set 2 | lodja
# Processing Record 44 of Set 2 | takoradi
# Processing Record 45 of Set 2 | dale
# Processing Record 46 of Set 2 | derac
# Processing Record 47 of Set 2 | bubaque
# Processing Record 48 of Set 2 | tura
# Processing Record 49 of Set 2 | nola
# Processing Record 50 of Set 2 | elko
# Processing Record 1 of Set 3 | castro
# Processing Record 2 of Set 3 | ventspils
# Processing Record 3 of Set 3 | chateauroux
# Processing Record 4 of Set 3 | marshfield
# Processing Record 5 of Set 3 | port elizabeth
# Processing Record 6 of Set 3 | lebu
# Processing Record 7 of Set 3 | galle
# Processing Record 8 of Set 3 | klaksvik
# Processing Record 9 of Set 3 | avarua
# Processing Record 10 of Set 3 | troitsko-pechorsk
# Processing Record 11 of Set 3 | zhumadian
# Processing Record 12 of Set 3 | cape canaveral
# Processing Record 13 of Set 3 | taoudenni
# Processing Record 14 of Set 3 | aklera
# Processing Record 15 of Set 3 | norman wells
# Processing Record 16 of Set 3 | nizhnyaya tavda
# Processing Record 17 of Set 3 | new norfolk
# Processing Record 18 of Set 3 | tezu
# Processing Record 19 of Set 3 | alofi
# Processing Record 20 of Set 3 | berlevag
# Processing Record 21 of Set 3 | richards bay
# Processing Record 22 of Set 3 | saint-joseph
# Processing Record 23 of Set 3 | barrow
# Processing Record 24 of Set 3 | helong
# Processing Record 25 of Set 3 | comodoro rivadavia
# Processing Record 26 of Set 3 | ponta do sol
# Processing Record 27 of Set 3 | anadyr
# Processing Record 28 of Set 3 | dawei
# Processing Record 29 of Set 3 | bethel
# Processing Record 30 of Set 3 | chipinge
# Processing Record 31 of Set 3 | solomenskoye
# Processing Record 32 of Set 3 | tautira
# Processing Record 33 of Set 3 | saint-pierre
# Processing Record 34 of Set 3 | port blair
# Processing Record 35 of Set 3 | jaramana
# City not found. Skipping...
# Processing Record 36 of Set 3 | coihaique
# Processing Record 37 of Set 3 | te anau
# Processing Record 38 of Set 3 | hammerfest
# Processing Record 39 of Set 3 | pio xii
# Processing Record 40 of Set 3 | olinda
# Processing Record 41 of Set 3 | puerto madryn
# Processing Record 42 of Set 3 | rawlins
# Processing Record 43 of Set 3 | puerto ayora
# Processing Record 44 of Set 3 | gilazi
# City not found. Skipping...
# Processing Record 45 of Set 3 | lincoln
# Processing Record 46 of Set 3 | svetlogorsk
# Processing Record 47 of Set 3 | road town
# Processing Record 48 of Set 3 | ozgon
# City not found. Skipping...
# Processing Record 49 of Set 3 | vardo
# Processing Record 50 of Set 3 | douala
# Processing Record 1 of Set 4 | chulumani
# Processing Record 2 of Set 4 | floro
# Processing Record 3 of Set 4 | ribeira grande
# Processing Record 4 of Set 4 | carnarvon
# Processing Record 5 of Set 4 | kruisfontein
# Processing Record 6 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 7 of Set 4 | ilulissat
# Processing Record 8 of Set 4 | houma
# Processing Record 9 of Set 4 | borujan
# City not found. Skipping...
# Processing Record 10 of Set 4 | zhezkazgan
# Processing Record 11 of Set 4 | clyde river
# Processing Record 12 of Set 4 | kovur
# Processing Record 13 of Set 4 | saint george
# Processing Record 14 of Set 4 | inirida
# Processing Record 15 of Set 4 | timbiqui
# Processing Record 16 of Set 4 | margate
# Processing Record 17 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 4 | alta floresta
# Processing Record 19 of Set 4 | georgetown
# Processing Record 20 of Set 4 | giurgiu
# Processing Record 21 of Set 4 | atuona
# Processing Record 22 of Set 4 | xining
# Processing Record 23 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 4 | muyezerskiy
# Processing Record 25 of Set 4 | kahului
# Processing Record 26 of Set 4 | mossendjo
# Processing Record 27 of Set 4 | berdigestyakh
# Processing Record 28 of Set 4 | velasco ibarra
# Processing Record 29 of Set 4 | hithadhoo
# Processing Record 30 of Set 4 | bengkulu
# Processing Record 31 of Set 4 | kununurra
# Processing Record 32 of Set 4 | obo
# Processing Record 33 of Set 4 | liaocheng
# Processing Record 34 of Set 4 | valley city
# Processing Record 35 of Set 4 | hilo
# Processing Record 36 of Set 4 | chuy
# Processing Record 37 of Set 4 | naze
# Processing Record 38 of Set 4 | constitucion
# Processing Record 39 of Set 4 | lagoa
# Processing Record 40 of Set 4 | linguere
# Processing Record 41 of Set 4 | saint-prosper
# Processing Record 42 of Set 4 | soyo
# Processing Record 43 of Set 4 | sitka
# Processing Record 44 of Set 4 | bang mun nak
# Processing Record 45 of Set 4 | kiama
# Processing Record 46 of Set 4 | borba
# Processing Record 47 of Set 4 | klyavlino
# Processing Record 48 of Set 4 | zeya
# Processing Record 49 of Set 4 | khatanga
# Processing Record 50 of Set 4 | upata
# Processing Record 1 of Set 5 | karratha
# Processing Record 2 of Set 5 | geraldton
# Processing Record 3 of Set 5 | areosa
# Processing Record 4 of Set 5 | kaitangata
# Processing Record 5 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 5 | westport
# Processing Record 7 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 5 | taburi
# City not found. Skipping...
# Processing Record 9 of Set 5 | zaraza
# Processing Record 10 of Set 5 | airai
# Processing Record 11 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 5 | saint-philippe
# Processing Record 13 of Set 5 | east london
# Processing Record 14 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 5 | mar del plata
# Processing Record 16 of Set 5 | iberia
# Processing Record 17 of Set 5 | isabela
# Processing Record 18 of Set 5 | marand
# Processing Record 19 of Set 5 | luena
# Processing Record 20 of Set 5 | nizwa
# Processing Record 21 of Set 5 | srednekolymsk
# Processing Record 22 of Set 5 | ketchikan
# Processing Record 23 of Set 5 | ondjiva
# Processing Record 24 of Set 5 | nikolskoye
# Processing Record 25 of Set 5 | sao joao da barra
# Processing Record 26 of Set 5 | zalantun
# Processing Record 27 of Set 5 | najran
# Processing Record 28 of Set 5 | san jose
# Processing Record 29 of Set 5 | nanortalik
# Processing Record 30 of Set 5 | mehamn
# Processing Record 31 of Set 5 | monrovia
# Processing Record 32 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 33 of Set 5 | moose factory
# Processing Record 34 of Set 5 | tasiilaq
# Processing Record 35 of Set 5 | fremont
# Processing Record 36 of Set 5 | nelson bay
# Processing Record 37 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 5 | tungkang
# City not found. Skipping...
# Processing Record 39 of Set 5 | honiara
# Processing Record 40 of Set 5 | buala
# Processing Record 41 of Set 5 | cidreira
# Processing Record 42 of Set 5 | vaitape
# Processing Record 43 of Set 5 | leningradskiy
# Processing Record 44 of Set 5 | el grullo
# Processing Record 45 of Set 5 | ostrovnoy
# Processing Record 46 of Set 5 | mayumba
# Processing Record 47 of Set 5 | tianpeng
# Processing Record 48 of Set 5 | buraydah
# Processing Record 49 of Set 5 | khor
# Processing Record 50 of Set 5 | pisco
# Processing Record 1 of Set 6 | palmer
# Processing Record 2 of Set 6 | faya
# Processing Record 3 of Set 6 | port-gentil
# Processing Record 4 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 5 of Set 6 | mao
# Processing Record 6 of Set 6 | isla mujeres
# Processing Record 7 of Set 6 | pauini
# Processing Record 8 of Set 6 | prince rupert
# Processing Record 9 of Set 6 | bambous virieux
# Processing Record 10 of Set 6 | marataizes
# Processing Record 11 of Set 6 | maxixe
# Processing Record 12 of Set 6 | boyolangu
# Processing Record 13 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 6 | kenai
# Processing Record 16 of Set 6 | buchanan
# Processing Record 17 of Set 6 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 18 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 6 | dinar
# Processing Record 20 of Set 6 | hambantota
# Processing Record 21 of Set 6 | carutapera
# Processing Record 22 of Set 6 | matagami
# Processing Record 23 of Set 6 | vostok
# Processing Record 24 of Set 6 | alice springs
# Processing Record 25 of Set 6 | padang
# Processing Record 26 of Set 6 | bikin
# Processing Record 27 of Set 6 | honningsvag
# Processing Record 28 of Set 6 | eureka
# Processing Record 29 of Set 6 | pevek
# Processing Record 30 of Set 6 | nong bua
# Processing Record 31 of Set 6 | asosa
# Processing Record 32 of Set 6 | iralaya
# Processing Record 33 of Set 6 | gat
# Processing Record 34 of Set 6 | benxi
# Processing Record 35 of Set 6 | vila
# Processing Record 36 of Set 6 | talnakh
# Processing Record 37 of Set 6 | longyearbyen
# Processing Record 38 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 6 | matara
# Processing Record 40 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 6 | bonthe
# Processing Record 42 of Set 6 | lengshuitan
# Processing Record 43 of Set 6 | mweka
# Processing Record 44 of Set 6 | boralday
# Processing Record 45 of Set 6 | xicotencatl
# Processing Record 46 of Set 6 | littleton
# Processing Record 47 of Set 6 | praia da vitoria
# Processing Record 48 of Set 6 | leua
# Processing Record 49 of Set 6 | shirhatti
# Processing Record 50 of Set 6 | keti bandar
# Processing Record 1 of Set 7 | fort nelson
# Processing Record 2 of Set 7 | zlobin
# Processing Record 3 of Set 7 | teguise
# Processing Record 4 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 5 of Set 7 | lavrentiya
# Processing Record 6 of Set 7 | college
# Processing Record 7 of Set 7 | taburao
# City not found. Skipping...
# Processing Record 8 of Set 7 | kautokeino
# Processing Record 9 of Set 7 | novopokrovka
# Processing Record 10 of Set 7 | cumberland
# Processing Record 11 of Set 7 | soe
# Processing Record 12 of Set 7 | sorland
# Processing Record 13 of Set 7 | aklavik
# Processing Record 14 of Set 7 | sursk
# Processing Record 15 of Set 7 | aquiraz
# Processing Record 16 of Set 7 | miri
# Processing Record 17 of Set 7 | necochea
# Processing Record 18 of Set 7 | loum
# Processing Record 19 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 20 of Set 7 | ancud
# Processing Record 21 of Set 7 | dryden
# Processing Record 22 of Set 7 | punta cardon
# Processing Record 23 of Set 7 | chokurdakh
# Processing Record 24 of Set 7 | thompson
# Processing Record 25 of Set 7 | bojnurd
# Processing Record 26 of Set 7 | svetlyy
# Processing Record 27 of Set 7 | betioky
# Processing Record 28 of Set 7 | dwarka
# Processing Record 29 of Set 7 | port lincoln
# Processing Record 30 of Set 7 | rockingham
# Processing Record 31 of Set 7 | mukhen
# Processing Record 32 of Set 7 | chifeng
# Processing Record 33 of Set 7 | jasper
# Processing Record 34 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 7 | guerrero negro
# Processing Record 36 of Set 7 | paragominas
# Processing Record 37 of Set 7 | potiskum
# Processing Record 38 of Set 7 | faanui
# Processing Record 39 of Set 7 | guinguineo
# Processing Record 40 of Set 7 | marshall
# Processing Record 41 of Set 7 | catumbela
# Processing Record 42 of Set 7 | taltal
# Processing Record 43 of Set 7 | viedma
# Processing Record 44 of Set 7 | formosa
# Processing Record 45 of Set 7 | nha trang
# Processing Record 46 of Set 7 | korla
# Processing Record 47 of Set 7 | atka
# City not found. Skipping...
# Processing Record 48 of Set 7 | bury saint edmunds
# City not found. Skipping...
# Processing Record 49 of Set 7 | camabatela
# Processing Record 50 of Set 7 | katsuura
# Processing Record 1 of Set 8 | smithers
# Processing Record 2 of Set 8 | batemans bay
# Processing Record 3 of Set 8 | paoua
# Processing Record 4 of Set 8 | hervey bay
# Processing Record 5 of Set 8 | qala
# Processing Record 6 of Set 8 | katherine
# Processing Record 7 of Set 8 | hami
# Processing Record 8 of Set 8 | napasar
# Processing Record 9 of Set 8 | kano
# Processing Record 10 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 8 | gigmoto
# Processing Record 12 of Set 8 | garowe
# Processing Record 13 of Set 8 | trincomalee
# Processing Record 14 of Set 8 | byron bay
# Processing Record 15 of Set 8 | panguna
# Processing Record 16 of Set 8 | pyapon
# Processing Record 17 of Set 8 | isangel
# Processing Record 18 of Set 8 | asfi
# Processing Record 19 of Set 8 | bay roberts
# Processing Record 20 of Set 8 | karamay
# City not found. Skipping...
# Processing Record 21 of Set 8 | south lake tahoe
# Processing Record 22 of Set 8 | uwajima
# Processing Record 23 of Set 8 | medzilaborce
# Processing Record 24 of Set 8 | terrace
# Processing Record 25 of Set 8 | beringovskiy
# Processing Record 26 of Set 8 | san quintin
# Processing Record 27 of Set 8 | aswan
# Processing Record 28 of Set 8 | broken hill
# Processing Record 29 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 30 of Set 8 | portland
# Processing Record 31 of Set 8 | madang
# Processing Record 32 of Set 8 | duz
# City not found. Skipping...
# Processing Record 33 of Set 8 | peterhead
# Processing Record 34 of Set 8 | arawa
# Processing Record 35 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 8 | ode
# Processing Record 37 of Set 8 | hudson bay
# Processing Record 38 of Set 8 | lahaina
# Processing Record 39 of Set 8 | arkadelphia
# Processing Record 40 of Set 8 | tateyama
# Processing Record 41 of Set 8 | vinh
# Processing Record 42 of Set 8 | dalby
# Processing Record 43 of Set 8 | araguacu
# Processing Record 44 of Set 8 | urusha
# Processing Record 45 of Set 8 | new bern
# Processing Record 46 of Set 8 | kungurtug
# Processing Record 47 of Set 8 | hokitika
# Processing Record 48 of Set 8 | codrington
# Processing Record 49 of Set 8 | dingle
# Processing Record 50 of Set 8 | tagusao
# Processing Record 1 of Set 9 | barabai
# Processing Record 2 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 9 | pemberton
# Processing Record 4 of Set 9 | san luis
# Processing Record 5 of Set 9 | kaiu
# Processing Record 6 of Set 9 | souillac
# Processing Record 7 of Set 9 | mogila
# Processing Record 8 of Set 9 | dunedin
# Processing Record 9 of Set 9 | nipawin
# Processing Record 10 of Set 9 | ixtapa
# Processing Record 11 of Set 9 | kavieng
# Processing Record 12 of Set 9 | henties bay
# Processing Record 13 of Set 9 | okato
# Processing Record 14 of Set 9 | ho
# City not found. Skipping...
# Processing Record 15 of Set 9 | san cristobal
# Processing Record 16 of Set 9 | saint anthony
# Processing Record 17 of Set 9 | hay river
# Processing Record 18 of Set 9 | vieux-habitants
# Processing Record 19 of Set 9 | morondava
# Processing Record 20 of Set 9 | meiganga
# Processing Record 21 of Set 9 | havoysund
# Processing Record 22 of Set 9 | muzhi
# Processing Record 23 of Set 9 | marawi
# Processing Record 24 of Set 9 | kutum
# Processing Record 25 of Set 9 | ulety
# Processing Record 26 of Set 9 | namatanai
# Processing Record 27 of Set 9 | chino valley
# Processing Record 28 of Set 9 | zyryanka
# Processing Record 29 of Set 9 | kuala lipis
# Processing Record 30 of Set 9 | roald
# Processing Record 31 of Set 9 | baykit
# Processing Record 32 of Set 9 | kurgan
# Processing Record 33 of Set 9 | shingu
# Processing Record 34 of Set 9 | dinahican
# Processing Record 35 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 36 of Set 9 | homer
# Processing Record 37 of Set 9 | mahibadhoo
# Processing Record 38 of Set 9 | wuwei
# Processing Record 39 of Set 9 | ayotzintepec
# Processing Record 40 of Set 9 | lakatoro
# Processing Record 41 of Set 9 | jinji
# Processing Record 42 of Set 9 | meulaboh
# Processing Record 43 of Set 9 | asau
# Processing Record 44 of Set 9 | sungairaya
# Processing Record 45 of Set 9 | kuusamo
# Processing Record 46 of Set 9 | derzhavinsk
# Processing Record 47 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 48 of Set 9 | phuthaditjhaba
# Processing Record 49 of Set 9 | paisley
# Processing Record 50 of Set 9 | oranjemund
# Processing Record 1 of Set 10 | tunduru
# City not found. Skipping...
# Processing Record 2 of Set 10 | paredon
# Processing Record 3 of Set 10 | nyurba
# Processing Record 4 of Set 10 | warren
# Processing Record 5 of Set 10 | san-pedro
# Processing Record 6 of Set 10 | huarmey
# Processing Record 7 of Set 10 | coquimbo
# Processing Record 8 of Set 10 | paamiut
# Processing Record 9 of Set 10 | lima
# Processing Record 10 of Set 10 | mbala
# Processing Record 11 of Set 10 | murowana goslina
# Processing Record 12 of Set 10 | rach gia
# Processing Record 13 of Set 10 | cervo
# Processing Record 14 of Set 10 | redmond
# Processing Record 15 of Set 10 | santa fe
# Processing Record 16 of Set 10 | mogadishu
# Processing Record 17 of Set 10 | kapoeta
# Processing Record 18 of Set 10 | severo-kurilsk
# Processing Record 19 of Set 10 | sorochinsk
# Processing Record 20 of Set 10 | cabedelo
# Processing Record 21 of Set 10 | thunder bay
# Processing Record 22 of Set 10 | laguna
# Processing Record 23 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 10 | ilo
# Processing Record 25 of Set 10 | dayong
# Processing Record 26 of Set 10 | pangoa
# Processing Record 27 of Set 10 | severo-yeniseyskiy
# Processing Record 28 of Set 10 | nantucket
# Processing Record 29 of Set 10 | ferrandina
# Processing Record 30 of Set 10 | ryotsu
# Processing Record 31 of Set 10 | andra
# Processing Record 32 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 33 of Set 10 | sarny
# Processing Record 34 of Set 10 | balabac
# Processing Record 35 of Set 10 | ust-kuyga
# Processing Record 36 of Set 10 | chenghai
# Processing Record 37 of Set 10 | antalaha
# Processing Record 38 of Set 10 | mareeba
# Processing Record 39 of Set 10 | ambon
# Processing Record 40 of Set 10 | mandalgovi
# Processing Record 41 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 42 of Set 10 | kirkuk
# Processing Record 43 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 44 of Set 10 | sadon
# Processing Record 45 of Set 10 | avera
# Processing Record 46 of Set 10 | polovinnoye
# Processing Record 47 of Set 10 | pahrump
# Processing Record 48 of Set 10 | nianzishan
# Processing Record 49 of Set 10 | thinadhoo
# Processing Record 50 of Set 10 | nador
# Processing Record 1 of Set 11 | sao jose da coroa grande
# Processing Record 2 of Set 11 | tempio pausania
# Processing Record 3 of Set 11 | atar
# Processing Record 4 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 5 of Set 11 | wanning
# Processing Record 6 of Set 11 | champerico
# Processing Record 7 of Set 11 | port-cartier
# Processing Record 8 of Set 11 | conde
# Processing Record 9 of Set 11 | payo
# Processing Record 10 of Set 11 | tselinnoye
# Processing Record 11 of Set 11 | chambersburg
# Processing Record 12 of Set 11 | gwembe
# Processing Record 13 of Set 11 | at-bashi
# Processing Record 14 of Set 11 | urumqi
# Processing Record 15 of Set 11 | handlova
# Processing Record 16 of Set 11 | bilibino
# Processing Record 17 of Set 11 | kolda
# Processing Record 18 of Set 11 | sur
# Processing Record 19 of Set 11 | pala
# Processing Record 20 of Set 11 | lindenberg
# Processing Record 21 of Set 11 | machico
# Processing Record 22 of Set 11 | vikindu
# Processing Record 23 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 24 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 25 of Set 11 | ukiah
# Processing Record 26 of Set 11 | yenagoa
# Processing Record 27 of Set 11 | kushima
# Processing Record 28 of Set 11 | kavaratti
# Processing Record 29 of Set 11 | andros town
# Processing Record 30 of Set 11 | alvand
# Processing Record 31 of Set 11 | komsomolskiy
# Processing Record 32 of Set 11 | ambilobe
# Processing Record 33 of Set 11 | rocky mountain house
# Processing Record 34 of Set 11 | mercedes
# Processing Record 35 of Set 11 | benguela
# Processing Record 36 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 37 of Set 11 | villamontes
# Processing Record 38 of Set 11 | bosaso
# Processing Record 39 of Set 11 | yiyang
# Processing Record 40 of Set 11 | troitskoye
# Processing Record 41 of Set 11 | snezhnogorsk
# Processing Record 42 of Set 11 | sorong
# Processing Record 43 of Set 11 | san felipe
# Processing Record 44 of Set 11 | majene
# Processing Record 45 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 46 of Set 11 | goderich
# Processing Record 47 of Set 11 | mitsamiouli
# Processing Record 48 of Set 11 | gamba
# Processing Record 49 of Set 11 | contamana
# Processing Record 50 of Set 11 | tuy hoa
# Processing Record 1 of Set 12 | bandipur
# Processing Record 2 of Set 12 | clifton
# Processing Record 3 of Set 12 | ashland
# Processing Record 4 of Set 12 | crab hill
# City not found. Skipping...
# Processing Record 5 of Set 12 | ye
# City not found. Skipping...
# Processing Record 6 of Set 12 | olafsvik
# Processing Record 7 of Set 12 | fairbanks
# Processing Record 8 of Set 12 | merauke
# Processing Record 9 of Set 12 | acapulco
# Processing Record 10 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 11 of Set 12 | teya
# Processing Record 12 of Set 12 | straumen
# Processing Record 13 of Set 12 | uvira
# Processing Record 14 of Set 12 | dauphin
# Processing Record 15 of Set 12 | verkhoyansk
# Processing Record 16 of Set 12 | aripuana
# Processing Record 17 of Set 12 | bonavista
# Processing Record 18 of Set 12 | kortkeros
# Processing Record 19 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 12 | nowa deba
# Processing Record 21 of Set 12 | sabang
# Processing Record 22 of Set 12 | muroto
# Processing Record 23 of Set 12 | maceio
# Processing Record 24 of Set 12 | porto novo
# Processing Record 25 of Set 12 | kasama
# Processing Record 26 of Set 12 | luderitz
# Processing Record 27 of Set 12 | mogocha
# Processing Record 28 of Set 12 | yugorsk
# Processing Record 29 of Set 12 | blagoyevo
# Processing Record 30 of Set 12 | lompoc
# Processing Record 31 of Set 12 | camacha
# Processing Record 32 of Set 12 | mindelo
# Processing Record 33 of Set 12 | ekhabi
# Processing Record 34 of Set 12 | arman
# Processing Record 35 of Set 12 | iskateley
# Processing Record 36 of Set 12 | bunbury
# Processing Record 37 of Set 12 | nouadhibou
# Processing Record 38 of Set 12 | yulara
# Processing Record 39 of Set 12 | kampene
# Processing Record 40 of Set 12 | tres arroyos
# Processing Record 41 of Set 12 | ende
# Processing Record 42 of Set 12 | sobolevo
# Processing Record 43 of Set 12 | simao
# Processing Record 44 of Set 12 | erenhot
# Processing Record 45 of Set 12 | nalut
# Processing Record 46 of Set 12 | krasnogorsk
# Processing Record 47 of Set 12 | gigante
# Processing Record 48 of Set 12 | balikpapan
# Processing Record 49 of Set 12 | yerbogachen
# Processing Record 50 of Set 12 | sao felix do xingu
# Processing Record 1 of Set 13 | lokomotivnyy
# Processing Record 2 of Set 13 | nizip
# Processing Record 3 of Set 13 | stromness
# Processing Record 4 of Set 13 | neryungri
# Processing Record 5 of Set 13 | saint-augustin
# Processing Record 6 of Set 13 | sechelt
# Processing Record 7 of Set 13 | kabare
# Processing Record 8 of Set 13 | ust-ilimsk
# Processing Record 9 of Set 13 | moscow
# Processing Record 10 of Set 13 | limon
# Processing Record 11 of Set 13 | jedburgh
# Processing Record 12 of Set 13 | lafia
# Processing Record 13 of Set 13 | washington
# Processing Record 14 of Set 13 | vila velha
# Processing Record 15 of Set 13 | ornskoldsvik
# Processing Record 16 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 13 | pimentel
# Processing Record 18 of Set 13 | kaniama
# Processing Record 19 of Set 13 | namibe
# Processing Record 20 of Set 13 | san jose iturbide
# Processing Record 21 of Set 13 | mirador
# Processing Record 22 of Set 13 | tamandare
# Processing Record 23 of Set 13 | grand-santi
# Processing Record 24 of Set 13 | tromso
# Processing Record 25 of Set 13 | half moon bay
# Processing Record 26 of Set 13 | karpogory
# Processing Record 27 of Set 13 | arlit
# Processing Record 28 of Set 13 | asyut
# Processing Record 29 of Set 13 | emerald
# Processing Record 30 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 13 | mawlaik
# Processing Record 32 of Set 13 | nam tha
# City not found. Skipping...
# Processing Record 33 of Set 13 | noyabrsk
# Processing Record 34 of Set 13 | nhulunbuy
# Processing Record 35 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 13 | anuchino
# Processing Record 37 of Set 13 | baturaja
# Processing Record 38 of Set 13 | hirara
# Processing Record 39 of Set 13 | claresholm
# Processing Record 40 of Set 13 | mangai
# Processing Record 41 of Set 13 | sisimiut
# Processing Record 42 of Set 13 | sivas
# Processing Record 43 of Set 13 | fare
# Processing Record 44 of Set 13 | stranda
# Processing Record 45 of Set 13 | waipawa
# Processing Record 46 of Set 13 | mbandaka
# Processing Record 47 of Set 13 | banamba
# Processing Record 48 of Set 13 | mildura
# Processing Record 49 of Set 13 | halifax
# Processing Record 50 of Set 13 | medea
# Processing Record 1 of Set 14 | vila franca do campo
# Processing Record 2 of Set 14 | thurso
# Processing Record 3 of Set 14 | muros
# Processing Record 4 of Set 14 | enshi
# Processing Record 5 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 6 of Set 14 | walvis bay
# Processing Record 7 of Set 14 | batouri
# Processing Record 8 of Set 14 | qaqortoq
# Processing Record 9 of Set 14 | vestmannaeyjar
# Processing Record 10 of Set 14 | gritsovskiy
# Processing Record 11 of Set 14 | boende
# Processing Record 12 of Set 14 | partenit
# Processing Record 13 of Set 14 | zhigansk
# Processing Record 14 of Set 14 | namli
# Processing Record 15 of Set 14 | ocampo
# Processing Record 16 of Set 14 | hovd
# Processing Record 17 of Set 14 | narasannapeta
# Processing Record 18 of Set 14 | porto santo
# Processing Record 19 of Set 14 | esperance
# Processing Record 20 of Set 14 | rio gallegos
# Processing Record 21 of Set 14 | camiri
# Processing Record 22 of Set 14 | gornopravdinsk
# Processing Record 23 of Set 14 | pareora
# Processing Record 24 of Set 14 | katobu
# Processing Record 25 of Set 14 | iquitos
# Processing Record 26 of Set 14 | pires do rio
# Processing Record 27 of Set 14 | kodinsk
# Processing Record 28 of Set 14 | high rock
# Processing Record 29 of Set 14 | zhongshu
# Processing Record 30 of Set 14 | zhuhai
# Processing Record 31 of Set 14 | inongo
# Processing Record 32 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 33 of Set 14 | doha
# Processing Record 34 of Set 14 | izhma
# Processing Record 35 of Set 14 | placido de castro
# Processing Record 36 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 37 of Set 14 | ejido
# Processing Record 38 of Set 14 | mayo
# Processing Record 39 of Set 14 | tiznit
# Processing Record 40 of Set 14 | moiyabana
# City not found. Skipping...
# Processing Record 41 of Set 14 | vallenar
# Processing Record 42 of Set 14 | venice
# Processing Record 43 of Set 14 | rocha
# Processing Record 44 of Set 14 | kyabe
# Processing Record 45 of Set 14 | saldanha
# Processing Record 46 of Set 14 | puerto escondido
# Processing Record 47 of Set 14 | port hardy
# Processing Record 48 of Set 14 | slave lake
# Processing Record 49 of Set 14 | alexandria
# Processing Record 50 of Set 14 | krasnaya gorka
# Processing Record 1 of Set 15 | ostersund
# Processing Record 2 of Set 15 | grebenskaya
# Processing Record 3 of Set 15 | manitouwadge
# Processing Record 4 of Set 15 | kedgwick
# Processing Record 5 of Set 15 | keelung
# Processing Record 6 of Set 15 | ust-maya
# Processing Record 7 of Set 15 | mount isa
# Processing Record 8 of Set 15 | diffa
# Processing Record 9 of Set 15 | porirua
# Processing Record 10 of Set 15 | thilogne
# City not found. Skipping...
# Processing Record 11 of Set 15 | kawardha
# Processing Record 12 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 15 | ayan
# Processing Record 14 of Set 15 | gravdal
# Processing Record 15 of Set 15 | general salgado
# Processing Record 16 of Set 15 | umm kaddadah
# Processing Record 17 of Set 15 | clonakilty
# Processing Record 18 of Set 15 | den helder
# Processing Record 19 of Set 15 | kizukuri
# Processing Record 20 of Set 15 | jiuquan
# Processing Record 21 of Set 15 | calais
# Processing Record 22 of Set 15 | tabou
# Processing Record 23 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 24 of Set 15 | krutinka
# Processing Record 25 of Set 15 | neftegorsk
# Processing Record 26 of Set 15 | srivardhan
# Processing Record 27 of Set 15 | gizo
# Processing Record 28 of Set 15 | new castle
# Processing Record 29 of Set 15 | troianul
# Processing Record 30 of Set 15 | chapais
# Processing Record 31 of Set 15 | sikonge
# Processing Record 32 of Set 15 | sonoita
# Processing Record 33 of Set 15 | pakxan
# Processing Record 34 of Set 15 | asbe teferi
# Processing Record 35 of Set 15 | kataysk
# Processing Record 36 of Set 15 | marzuq
# Processing Record 37 of Set 15 | colares
# Processing Record 38 of Set 15 | jacareacanga
# Processing Record 39 of Set 15 | kysyl-syr
# Processing Record 40 of Set 15 | solnechnyy
# Processing Record 41 of Set 15 | puerto colombia
# Processing Record 42 of Set 15 | kaputa
# Processing Record 43 of Set 15 | daru
# Processing Record 44 of Set 15 | mangrol
# Processing Record 45 of Set 15 | santa rosa
# Processing Record 46 of Set 15 | khakhea
# Processing Record 47 of Set 15 | teknaf
# Processing Record 48 of Set 15 | bambari
# Processing Record 49 of Set 15 | koboldo
# City not found. Skipping...
# Processing Record 50 of Set 15 | kolokani
# Processing Record 1 of Set 16 | barawe
# City not found. Skipping...
# Processing Record 2 of Set 16 | providencia
# Processing Record 3 of Set 16 | shahr-e babak
# Processing Record 4 of Set 16 | lorton
# Processing Record 5 of Set 16 | oistins
# Processing Record 6 of Set 16 | landeck
# Processing Record 7 of Set 16 | molchanovo
# Processing Record 8 of Set 16 | suao
# City not found. Skipping...
# Processing Record 9 of Set 16 | bianzhuang
# Processing Record 10 of Set 16 | zhaoyang
# Processing Record 11 of Set 16 | utinga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Pochutla      MX  15.7432  -96.4661     88.83        40          72
# 1            Kihei      US  20.7850 -156.4656     87.82        51          20
# 2           Kodiak      US  57.7900 -152.4072     47.71        76         100
# 3    Mount Gambier      AU -37.8333  140.7667     40.91       100          13
# 4            Kapaa      US  22.0752 -159.3190     80.58        78          20
# 5            Vaini      TO -21.2000 -175.2000     80.76        78          20
# 6  Plettenberg Bay      ZA -34.0527   23.3716     56.43        80          88
# 7           Khasan      RU  42.4308  130.6434     55.49        78          28
# 8            Tingi      TZ -11.3000   35.0333     61.47        95          63
# 9          Dolores      AR -36.3132  -57.6792     53.11        64          97
#
#    Wind Speed Current Description
# 0       12.48       broken clouds
# 1       13.80          few clouds
# 2       17.27     overcast clouds
# 3        0.00          few clouds
# 4        9.22          light rain
# 5        6.91          few clouds
# 6        6.87          light rain
# 7        2.75    scattered clouds
# 8        4.61       broken clouds
# 9        5.97     overcast clouds

# %%
# Create the output file (CSV).

output_data_file = "WeatherPY_Database.csv"

# Export the City_Data into a CSV.

city_data_df.to_csv(output_data_file, index_label="City_ID")
